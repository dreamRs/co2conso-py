# %%
import sys
sys.path.insert(0, "..")

import importlib
import helpers
importlib.reload(helpers)
from helpers import *
from collect import *

df = charger_donnees()
df["date_heure_cet"] = df["date_heure_utc"].dt.tz_convert("Europe/Paris")
fig = courbe(df)
fig.show()
